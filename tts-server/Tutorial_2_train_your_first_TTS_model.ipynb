# %% [markdown]
# # Train your first 🐸 TTS model 💫
#
# ### 👋 Hello and welcome to Coqui (🐸) TTS
#
# The goal of this notebook is to show you a **typical workflow** for **training** and **testing** a TTS model with 🐸.
#
# Let's train a very small model on a very small amount of data so we can iterate quickly.
#
# In this notebook, we will:
#
# 1. Download data and format it for 🐸 TTS.
# 2. Configure the training and testing runs.
# 3. Train a new model.
# 4. Test the model and display its performance.
#
# So, let's jump right in!

# %% [markdown]
# ## ✅ Data Preparation
#
# ### **First things first**: we need some data.
#
# We're training a Text-to-Speech model, so we need some _text_ and we need some _speech_. Specificially, we want _transcribed speech_. The speech must be divided into audio clips and each clip needs transcription. More details about data requirements such as recording characteristics, background noise and vocabulary coverage can be found in the [🐸TTS documentation](https://tts.readthedocs.io/en/latest/formatting_your_dataset.html).
#
# If you have a single audio file and you need to **split** it into clips. It is also important to use a lossless audio file format to prevent compression artifacts. We recommend using **wav** file format.
#
# The data format we will be adopting for this tutorial is taken from the widely-used  **LJSpeech** dataset, where **waves** are collected under a folder:
#
# <span style="color:purple;font-size:15px">
# /wavs<br />
#  &emsp;| - audio1.wav<br />
#  &emsp;| - audio2.wav<br />
#  &emsp;| - audio3.wav<br />
#   ...<br />
# </span>
#
# and a **metadata.csv** file will have the audio file name in parallel to the transcript, delimited by `|`:
#
# <span style="color:purple;font-size:15px">
# # metadata.csv <br />
# audio1|This is my sentence. <br />
# audio2|This is maybe my sentence. <br />
# audio3|This is certainly my sentence. <br />
# audio4|Let this be your sentence. <br />
# ...
# </span>
#
# In the end, we should have the following **folder structure**:
#
# <span style="color:purple;font-size:15px">
# /MyTTSDataset <br />
# &emsp;| <br />
# &emsp;| -> metadata.csv<br />
# &emsp;| -> /wavs<br />
# &emsp;&emsp;| -> audio1.wav<br />
# &emsp;&emsp;| -> audio2.wav<br />
# &emsp;&emsp;| ...<br />
# </span>

# %% [markdown]
# 🐸TTS already provides tooling for the _LJSpeech_. if you use the same format, you can start training your models right away. <br />
#
# After you collect and format your dataset, you need to check two things. Whether you need a **_formatter_** and a **_text_cleaner_**. <br /> The **_formatter_** loads the text file (created above) as a list and the **_text_cleaner_** performs a sequence of text normalization operations that converts the raw text into the spoken representation (e.g. converting numbers to text, acronyms, and symbols to the spoken format).
#
# If you use a different dataset format then the LJSpeech or the other public datasets that 🐸TTS supports, then you need to write your own **_formatter_** and  **_text_cleaner_**.

# %% [markdown]
# ## ⏳️ Loading your dataset
# Load one of the dataset supported by 🐸TTS.
#
# We will start by defining dataset config and setting LJSpeech as our target dataset and define its path.

# %% [markdown]
# ## ✅ Train a new model
#
# Let's kick off a training run 🚀🚀🚀.
#
# Deciding on the model architecture you'd want to use is based on your needs and available resources. Each model architecture has it's pros and cons that define the run-time efficiency and the voice quality.
# We have many recipes under `TTS/recipes/` that provide a good starting point. For this tutorial, we will be using `GlowTTS`.

# %% [markdown]
# We will begin by initializing the model training configuration.

# %%
import os

from trainer import Trainer, TrainerArgs

from TTS.config.shared_configs import BaseDatasetConfig
from TTS.tts.datasets import load_tts_samples
from TTS.tts.layers.xtts.trainer.gpt_trainer import GPTArgs, GPTTrainer, GPTTrainerConfig, XttsAudioConfig
from TTS.utils.manage import ModelManager

# Logging parameters
RUN_NAME = "GPT_XTTS_v2.0"
PROJECT_NAME = "XTTS_trainer"
DASHBOARD_LOGGER = "tensorboard"
LOGGER_URI = None

OUT_PATH = os.path.join("./test", "run", "train_outputs")

# Training Parameters
OPTIMIZER_WD_ONLY_ON_WEIGHTS = True  # for multi-gpu training please make it False
START_WITH_EVAL = True  # if True it will star with evaluation
BATCH_SIZE = 3  # set here the batch size
GRAD_ACUMM_STEPS = 84  # set here the grad accumulation steps
# Note: we recommend that BATCH_SIZE * GRAD_ACUMM_STEPS need to be at least 252 for more efficient training. You can increase/decrease BATCH_SIZE but then set GRAD_ACUMM_STEPS accordingly.


test_path = os.path.join(os.getcwd(),"dataset", "actors", "anime_001", "H1")
config_dataset = BaseDatasetConfig(
    formatter="ljspeech",
    dataset_name="dragon",
    path=test_path,
    meta_file_train="metadata.csv",
    meta_file_val="metadataVal.csv",
    language="ko",
)

DATASETS_CONFIG_LIST = [config_dataset]


# Define the path where XTTS v2.0.1 files will be downloaded
CHECKPOINTS_OUT_PATH = os.path.join(OUT_PATH, "XTTS_v2.0_original_model_files/")
os.makedirs(CHECKPOINTS_OUT_PATH, exist_ok=True)


# DVAE files
DVAE_CHECKPOINT_LINK = "https://coqui.gateway.scarf.sh/hf-coqui/XTTS-v2/main/dvae.pth"
MEL_NORM_LINK = "https://coqui.gateway.scarf.sh/hf-coqui/XTTS-v2/main/mel_stats.pth"

# Set the path to the downloaded files
DVAE_CHECKPOINT = os.path.join(CHECKPOINTS_OUT_PATH, os.path.basename(DVAE_CHECKPOINT_LINK))
MEL_NORM_FILE = os.path.join(CHECKPOINTS_OUT_PATH, os.path.basename(MEL_NORM_LINK))

# download DVAE files if needed
if not os.path.isfile(DVAE_CHECKPOINT) or not os.path.isfile(MEL_NORM_FILE):
    print(" > Downloading DVAE files!")
    ModelManager._download_model_files([MEL_NORM_LINK, DVAE_CHECKPOINT_LINK], CHECKPOINTS_OUT_PATH, progress_bar=True)


# Download XTTS v2.0 checkpoint if needed
TOKENIZER_FILE_LINK = "https://coqui.gateway.scarf.sh/hf-coqui/XTTS-v2/main/vocab.json"
XTTS_CHECKPOINT_LINK = "https://coqui.gateway.scarf.sh/hf-coqui/XTTS-v2/main/model.pth"

# XTTS transfer learning parameters: You we need to provide the paths of XTTS model checkpoint that you want to do the fine tuning.
TOKENIZER_FILE = os.path.join(CHECKPOINTS_OUT_PATH, os.path.basename(TOKENIZER_FILE_LINK))  # vocab.json file
XTTS_CHECKPOINT = os.path.join(CHECKPOINTS_OUT_PATH, os.path.basename(XTTS_CHECKPOINT_LINK))  # model.pth file

# download XTTS v2.0 files if needed
if not os.path.isfile(TOKENIZER_FILE) or not os.path.isfile(XTTS_CHECKPOINT):
    print(" > Downloading XTTS v2.0 files!")
    ModelManager._download_model_files(
        [TOKENIZER_FILE_LINK, XTTS_CHECKPOINT_LINK], CHECKPOINTS_OUT_PATH, progress_bar=True
    )

LANGUAGE = config_dataset.language

# init args and config
model_args = GPTArgs(
    max_conditioning_length=132300,  # 6 secs
    min_conditioning_length=66150,  # 3 secs
    debug_loading_failures=False,
    max_wav_length=255995,  # ~11.6 seconds
    max_text_length=200,
    mel_norm_file=MEL_NORM_FILE,
    dvae_checkpoint=DVAE_CHECKPOINT,
    xtts_checkpoint=XTTS_CHECKPOINT,  # checkpoint path of the model that you want to fine-tune
    tokenizer_file=TOKENIZER_FILE,
    gpt_num_audio_tokens=1026,
    gpt_start_audio_token=1024,
    gpt_stop_audio_token=1025,
    gpt_use_masking_gt_prompt_approach=True,
    gpt_use_perceiver_resampler=True,
)
# define audio config
audio_config = XttsAudioConfig(sample_rate=22050, dvae_sample_rate=22050, output_sample_rate=24000)
# training parameters config
config = GPTTrainerConfig(
    output_path=OUT_PATH,
    model_args=model_args,
    run_name=RUN_NAME,
    project_name=PROJECT_NAME,
    run_description="""
        GPT XTTS training
        """,
    dashboard_logger=DASHBOARD_LOGGER,
    logger_uri=LOGGER_URI,
    audio=audio_config,
    batch_size=BATCH_SIZE,
    batch_group_size=48,
    eval_batch_size=BATCH_SIZE,
    num_loader_workers=8,
    eval_split_max_size=256,
    print_step=50,
    plot_step=100,
    log_model_step=1000,
    save_step=10000,
    save_n_checkpoints=1,
    save_checkpoints=True,
    # target_loss="loss",
    print_eval=False,
    # Optimizer values like tortoise, pytorch implementation with modifications to not apply WD to non-weight parameters.
    optimizer="AdamW",
    optimizer_wd_only_on_weights=OPTIMIZER_WD_ONLY_ON_WEIGHTS,
    optimizer_params={"betas": [0.9, 0.96], "eps": 1e-8, "weight_decay": 1e-2},
    lr=5e-06,  # learning rate
    lr_scheduler="StepLR",
    # it was adjusted accordly for the new step scheme
    lr_scheduler_params={"step_size": 50, "gamma": 0.5, "last_epoch": -1}
)

# init the model from config
model = GPTTrainer.init_from_config(config)

# load training samples
train_samples, eval_samples = load_tts_samples(
    DATASETS_CONFIG_LIST,
    eval_split=True,
    eval_split_max_size=config.eval_split_max_size,
    eval_split_size=config.eval_split_size,
)

# %%
train_samples
# Out:
# [{'text': '사악한 기운과 더러운 독기를 모조리 다 정화시키는 이 힘은 축복이야.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10101.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10101'},
#  {'text': '이것만 있으면 사업을 번창하게 하고 가정도 평화롭게 할 수 있대, 어때, 좋지?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10102.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10102'},
#  {'text': '우리 귀여운 손녀딸에게 집안 대대로 물려 내려오는 구슬을 선물로 주마!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10103.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10103'},
#  {'text': '약소하지만 행운을 가져다주는 복주머니야, 이번 시험 잘 봐!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10104.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10104'},
#  {'text': '사과 안 해도 돼요, 만약에 당신이 없었으면 우리 전부 다 이 자리에서 죽었을 겁니다.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10105.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10105'},
#  {'text': '그래, 너 지금까지 본 모습 중 제일 굉장했어, 덕분에 살았다.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10106.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10106'},
#  {'text': '어, 저기 봐, 우리 집 앞 슈퍼마켓이 보여~ 제대로 찾아왔나 봐, 다행이야!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10107.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10107'},
#  {'text': '어머나, 너희들 아직 몰랐구나, 할아버지께서 우리한테 얼마나 많은 도움을 주셨는데!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10108.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10108'},
#  {'text': '헹~ 내 실력 봤지, 그러니까 이제 까불지 마~!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10109.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10109'},
#  {'text': '마음만 먹으면 너 같은 건 한 방에 끝장낼 수 있다고!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10110.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10110'},
#  {'text': '우리 시간도 남는데 이 근처에 있는 곳에 놀러가지 않을래, 가서 재밌게 놀자!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10111.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10111'},
#  {'text': '너, 솔직히 말해~ 요새 너무 수상해.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10112.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10112'},
#  {'text': '학교 가기 전에 거울 보는 시간도 길어지고, 학교에 좋아하는 친구 있지?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10113.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10113'},
#  {'text': '있잖아, 난 오래전부터 아이돌이 되는 게 꿈이었어.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10114.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10114'},
#  {'text': '다들 어린애가 무슨 아이돌을 하냐고 한마디씩 하는데~.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10115.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10115'},
#  {'text': '난 꼭 노력해서 내 꿈에 한 발짝씩 다가갈 거야, 너도 응원해 줄 거지?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10116.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10116'},
#  {'text': '너 아이돌이 되고 싶구나, 문제없어.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10117.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10117'},
#  {'text': '모두에게 전하는 거야, 힘차게 노래를 불러줘, 온 세상에 다 들리게!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10118.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10118'},
#  {'text': '너를 좋아하면서부터 내 마음속에 무지개가 떴어, 하루하루가 꿈꾸는 기분이야.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10119.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10119'},
#  {'text': '아까 그 무대, 꿈을 꾸듯 푹 빠졌더니 어떻게 지나갔는지 생각도 안 나~ 혹시 진짜 꿈이었나?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10120.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10120'},
#  {'text': '나 계속 열심히 환상적으로 아이돌 시계를 모을 거야, 그래서 진짜 꿈꿨던 아이돌이 되겠어!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10121.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10121'},
#  {'text': '밥알이 입안에서 탱글탱글 살아움직이는 느낌이야~ 맛있어!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10122.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10122'},
#  {'text': '나도 저렇게 운동을 잘하면 좋을 텐데~ 니아의 환상적인 점프를 보시라, 생각만 해도 멋지다!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10123.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10123'},
#  {'text': '나 오늘부터 다이어트하려고 했는데,  또 하나도 안 남기고 다 먹어버렸네~!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10124.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10124'},
#  {'text': '어, 아빠 로봇 몸에서 뭔가 나왔어요, 이게 뭐죠?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10125.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10125'},
#  {'text': '히~ 이걸 움직이니까 아빠가 내 맘대로 움직여요, 이제부턴 아빠가 내 부하예요, 신난다!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10126.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10126'},
#  {'text': '그렇지, 비록 몸은 이렇게 됐지만 로봇이라 편한 게 많아.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10127.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10127'},
#  {'text': '이거 봐, 다리로 선풍기를 만들 수도 있어, 짱 신기하지?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10128.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10128'},
#  {'text': '사랑아~ 엄마 좀 봐봐~ 요새 다이어트를 했더니 살 빠진 거 같지 않니, 잘 좀 봐봐!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10129.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10129'},
#  {'text': '아싸~ 이 옷이 드디어 맞다니, 한 달 굶은 효력이 이제 나타나나 봐!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10130.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10130'},
#  {'text': '오랫동안 기다렸지, 나의 꿈의 원피스, 흐흐흐~ 내가 곧 입어 주마!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10131.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10131'},
#  {'text': '여보, 내가 만든 요리 어때, 맛있어, 맛있으면 빨리 칭찬해줘, 빨리, 빨리!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10132.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10132'},
#  {'text': '어머~ 이거 보여, 턱 선 날렵해진 거 봐, 이러다 내 턱선에 손 베겠어~ 아야!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10133.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10133'},
#  {'text': '이거 왜 이래~ 이젠 예전의 내가 아니거든, 앞으로는 뱃살 공주라고 부르지 말아 줄래?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10134.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10134'},
#  {'text': '요리도 잘하고, 집안 구석구석 수리도 하고, 로봇 남편도 뭐 그렇게 나쁘지만은 않네요.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10135.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10135'},
#  {'text': '걱정 붙들어 매, 난 지금보다 더 멋지고 굉장한 사람이 될 거야, 두고 봐!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10136.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10136'},
#  {'text': '얘들아~ 우리가 타고 온 배를 찾았어, 서둘러 돌아오지 않으면 나 혼자 빠져나간다~ 메롱!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10137.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10137'},
#  {'text': '이 녀석~ 누가 놓칠까 보냐~ 믿음아~ 어서 내 고무 팔에 매달려, 단숨에 날아가 주지!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10138.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10138'},
#  {'text': '그 황금땅은 바다로 가라앉은 게 아니었어, 하늘에 떠 있었던 거야!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10139.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10139'},
#  {'text': '아아~ 고생 끝에 도착한 하늘 위의 섬, 그게 황금땅이었을 줄이야.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10140.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10140'},
#  {'text': '이건 평소에 착하게 살아온 저에 대한 신의 선물인 거죠?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10141.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10141'},
#  {'text': '너가 하는 얘기를 들을 때마다 가슴이 두근두근해~ 오늘은 또 어떤 모험 얘기를 해줄 거야?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10142.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10142'},
#  {'text': '저는 당신을 지키기 위해서 이곳에 남았습니다, 그러니까 안심하고 푹 쉬세요.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10143.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10143'},
#  {'text': '너무나도 잘생긴 남자의 모습에, 몸에서 반짝반짝 빛이 나는 요괴였어.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10144.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10144'},
#  {'text': '그리고 우리 두 사람은 불타는 사랑에 빠졌지.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10145.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10145'},
#  {'text': '뭐, 진짜, 그렇게 지독하게 괴롭히던 그 여자가 죽었단 말이야, 흥, 속 시원~하다.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10146.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10146'},
#  {'text': '소망이는 요괴라 덩치가 커서 그렇지 마음씨는 너무 착해 빠졌단 말야.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10147.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10147'},
#  {'text': '여러분이 이 세상을 구할 수 있어요, 그래서 여러분의 다짐이 꼭 필요해요! \n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10148.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10148'},
#  {'text': '보아라~ 이 얼마나 아름다운 세상인가!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10149.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10149'},
#  {'text': '와, 이것 봐, 내 손에 파랑새가 앉았어, 이런 경험 처음이야!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10150.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10150'},
#  {'text': '자, 이것 봐요, 제 손에 참새가 앉았어요, 저 이런 경험 처음이에요!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10151.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10151'},
#  {'text': '아~ 이런 게 즐겁다는 느낌이구나~ 다른 사람과 마주보면서 웃는 게 얼마 만인지.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10152.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10152'},
#  {'text': '안녕, 얘들아~ 난 오늘 이 학교로 전학 온 사랑이야, 다들 만나서 반가워!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10153.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10153'},
#  {'text': '그럼, 첫 시간은 전학 온 사랑이를 위해 학교 구경을 시켜주는 건 어때?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10154.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10154'},
#  {'text': '어렵고 힘든 일이 있더라도 우리가 신급 아이돌이 되려고 노력했던 때를 다시 생각해 봐.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10155.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10155'},
#  {'text': '지금 이 정도는 아무것도 아니야, 할 수 없는 것은 아무것도 없다고!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10156.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10156'},
#  {'text': '여기가 우리 학교에서 제일 맛있는 빵을 파는 매점이야, 바로 우리 학교의 자랑이지.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10157.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10157'},
#  {'text': '비록 기억이 지워지더라도 다시 한번 친구가 되어 줘, 잘 부탁해.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10158.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10158'},
#  {'text': '정 들면 고향, 정 들면 고향, 하아~ 벌써 포근하게 느껴지는걸?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10159.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10159'},
#  {'text': '그럼, 제가 학생들을 위해 식사 준비를 하겠습니다, 저를 믿고 맡겨만 주세요!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10160.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10160'},
#  {'text': '매일 혼자 하던 거였는데 너가 들어오고 나서 일이 정말 편해졌어, 고마워.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10161.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10161'},
#  {'text': '대박, 이거 진짜 최고다, 이렇게 변한 게 진짜 나 맞지, 우리 엄마도 몰라볼 정도로 예뻐졌어!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10162.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10162'},
#  {'text': '어, 엄마, 어떻게 아셨어요, 저 이 책 꼭 갖고 싶었던 거예요, 엄마, 고마워요!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10163.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10163'},
#  {'text': '좋겠다, 오늘 엄마랑 소풍 가는 날이지?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10164.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10164'},
#  {'text': '가서 엄마랑 선생님 말씀 잘 듣고, 위험한데 가지 말고, 아빠랑 약속!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10165.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10165'},
#  {'text': '아빠가 로봇이 됐다고 친구들한테 자랑하면 다들 부러워할 텐데, 조금만 자랑하면 안 돼요?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10166.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10166'},
#  {'text': '먹어보니까 어때, 내 말이 맞지, 이 집에서는 이게 제일 맛있다니까.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10167.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10167'},
#  {'text': '하아~ 맛있는 걸 먹고 있자니 내 몸이 솜사탕처럼 녹고 있는 거 같아요, 기분이 좋아져요.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10168.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10168'},
#  {'text': '아유~ 우리 남편도 로봇이라면 얼마나 좋을까요?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10169.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10169'},
#  {'text': '그럼 잠도 자지 않고 일하면서 돈도 벌어올 텐데, 호호호~.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10170.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10170'},
#  {'text': '정말 굉장하다, 우리나라 로봇 산업이 이렇게 발전했다니, 눈으로 직접 보고도 믿기지 않아.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10171.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10171'},
#  {'text': '우리 집엔 더 굉장한 것도 있는데~ 궁금하지, 근데 말 안 해 줄 거임!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10172.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10172'},
#  {'text': '엄마한테도 말하면 안 돼, 이건 우리들끼리만 아는 비밀~!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10173.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10173'},
#  {'text': '이제 안심해, 당신 두고 다신 어디에도 안 갈 테니까, 맹세하라면 할게.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10174.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10174'},
#  {'text': '얏호~ 바람을 타고 물기둥 위를 배가 수직으로 달리고 있잖아, 좋았어, 이 상태로 구름까지!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10175.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10175'},
#  {'text': '친구야~ 요즘 부쩍 우울해 보이는데, 기운 나게 내가 재밌는 얘기 하나 해줄까?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10176.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10176'},
#  {'text': '좋은 소식이 뭔데, 혹시 내가 찾던 거, 벌써 찾은 거야? \n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10177.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10177'},
#  {'text': '자, 이거~ 너한테 주는 거야, 요새 나한테 너무 잘해 줘서 뭔가 성의를 표시하고 싶었거든.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10178.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10178'},
#  {'text': '앗, 저깄다~ 소망 누님~ 사랑의 시련을 뛰어넘어 제가 왔쪄용~ 사랑의 하트는 덤입니당~!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10179.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10179'},
#  {'text': '사람들이 말하던 장소가 여기야, 그런데 정말 여기에 보물이 묻혀 있을까, 빨리 파 보자!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10180.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10180'},
#  {'text': '불 탄 게 너가 아니라 배라서 다행이야, 하하하~ 배에 대해선 나중에 다시 생각해 보자고!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10181.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10181'},
#  {'text': '해적이 보물을 눈앞에 두고 가만히 있을 수는 없지.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10182.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10182'},
#  {'text': '게다가 적도 많으니 서바이벌이 되려나, 이거 기대되는데?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10183.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10183'},
#  {'text': '오호~ 그건 바로 소금 결정, 니아 양은 참 좋은 걸 찾아왔네요.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10184.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10184'},
#  {'text': '이 녀석과 함께 있으면 어쩐지 일이 술술 풀릴 거 같단 말이지, 느낌이 좋아.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10185.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10185'},
#  {'text': '이 약초는 상처 난 데 바르면 좋아요, 제가 고마워서 드리는 것이니 신경 쓰지 않으셔도 돼요.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10186.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10186'},
#  {'text': '너가 나한테 너의 얘기를 해주는 건 처음이야, 직접 너한테 이 얘길 들으니 기쁘다.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10187.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10187'},
#  {'text': '뭐 어때, 나한테 네 신세타령을 해도 좋아, 그게 다 외톨이가 아니니까 그런 거지.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10188.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10188'},
#  {'text': '언제부턴가 마치 당연하다는 듯이 사랑이가 내 곁에 있어, 난 외톨이가 아냐.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10189.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10189'},
#  {'text': '아이고~ 살았다, 이번 요괴와의 싸움에서 목숨을 건진 것만 해도 다행이야~ 휴.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10190.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10190'},
#  {'text': '빵하고도, 부침개하고도, 라면하고도 어떤 것하고도 잘 어울리는 평화주의자라고.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10191.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10191'},
#  {'text': '네, 사랑이는 학교가 좋아요, 학교에 오면 즐겁고 행복한 일이 많이 생겨요.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10192.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10192'},
#  {'text': '저기~ 오늘 학교 끝나고 뭐해, 시간 맞으면 나랑 노는 건 어때?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10193.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10193'},
#  {'text': '얘들아~ 나  초능력자인가 봐, 지하철에서 내릴 사람을 딱 알아본다니까.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10194.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10194'},
#  {'text': '와~ 대단하다, 알고 보니 초능력자가 내 친구라는 건가, 하하하~ 뭔가 으쓱한 기분인데?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10195.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10195'},
#  {'text': '어떻게 망친 시험지를 여기에 숨겨놓은 걸 알아챈 거지?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10196.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10196'},
#  {'text': '정말로 엄마는 엉뚱하게 감이 좋다니까, 리스펙~!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10197.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10197'},
#  {'text': '뭐냐, 그 체육복은~ 하하하~ 설마 나 웃기려고 입은 건 아니지?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10198.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10198'},
#  {'text': '어떻게 알았어요,마침 오늘 저녁이 카레인데, 오늘따라 갑자기 카레가 당겨서 준비했어요!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10199.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10199'},
#  {'text': '아빠, 회사 잘 다녀오셨어요, 오늘도 가족들을 위해 돈 버시느라 수고하셨어요~! \n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10200.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10200'},
#  {'text': '이 표시가 된 곳을 찾으면 네가 파묻어 놓은 용돈을 찾을 수 있을 거야, 잘 갔다 와!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10201.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10201'},
#  {'text': '진짜요, 그거 당첨되기 엄청 힘들다고 하던데~ 정말 축하드려요!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10202.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10202'},
#  {'text': '그야 당연하죠, 서바이벌에 있어서 목숨과 직결된 것이 염분인데~ 참 좋은 걸 구해 오셨어요!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10203.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10203'},
#  {'text': '틀림없어, 이 해골의 오른쪽 눈 속에 막대한 황금이 있을 거야, 암.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10204.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10204'},
#  {'text': '오옷~ 이상한 기사님 일어나셨네, 우리 동료를 구해줘서 고마워, 우리 같이 춤추자!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10205.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10205'},
#  {'text': '도움이 필요할 땐 내 이름을 불러, 그럼 빛의 속도로 너에게 날아갈게.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10206.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10206'},
#  {'text': '오케이~ 지금부터 황금 사냥에 나설 시간이다, 사냥이 끝나면 우린 부자가 되는 거지!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10207.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10207'},
#  {'text': '이야~ 역시 제독님이십니다~ 제독님의 말씀대로 키를 잡았더니 정말 섬에 도착했어요!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10208.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10208'},
#  {'text': '킁킁~ 어디서 맛있는 냄새가 나는데, 어디지, 어, 저쪽이다, 나를 따르라!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10209.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10209'},
#  {'text': '찾았다~ 여기 진짜 먹음직스러운 버섯 천지야~ 얘들아~ 빨리 이쪽으로 와 봐!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10210.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10210'},
#  {'text': '단서는 다 찾았어, 이제 남은  건 이걸 어떻게 짜 맞추느냐 하는 건데~.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10211.wav',
# ...
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10434'},
#  {'text': '1억만 있으면 난 이 마을을 살 수 있어, 그리고 마을 사람들을 악당에게서 해방시키는 거야.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10435.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10435'},
#  {'text': '이번 이벤트 퀴즈의 답은 내가 알아요, 우리 참여해 봐요, 상품은 우리 거라고요!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10436.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10436'},
#  {'text': '좋았어, 내일 방과 후에 다 함께 귀신 찾으러 가자, 추리특공대 출동!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10437.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10437'},
#  {'text': '요즘은 살인사건이 없어서 탐정님 시간도 많잖아요, 우리 돌고래 보러 가요!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10438.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10438'},
#  {'text': '오늘 사랑이 생일인데, 사랑이 몰래 깜짝파티 하는 건 어때?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10439.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10439'},
#  {'text': '당신이 그 유명한 홍길동 탐정님이시군요, 몰라봐서 죄송해요, 실물이 훨씬 잘생겼네요!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10440.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10440'},
#  {'text': '이 정도쯤이야, 탐정이라면 누구나 생각할 줄 알아야겠지, 추리의 기본 중에 기본이란다.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10441.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10441'},
#  {'text': '봄이야, 봄에는 게임이지, 우리 다같이 게임하자~!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10442.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10442'},
#  {'text': '불의에도 굴하지 않고 덤비는 모습이 멋있어 보여, 미약하나마 내가 도움이 됐음 좋겠어.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10443.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10443'},
#  {'text': '이걸 입은 내 모습, 샤방샤방 엄청 귀엽겠지, 남자아이들도 다 나만 쳐다볼 텐데~ 어떡해!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10444.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10444'},
#  {'text': '넌 정말 상냥해, 그래서 보고 있으면 행복해서 방긋 웃고 싶어질 정도야.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10445.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10445'},
#  {'text': '전 행복초등학교 6학년 2반 김사랑이라고 해요.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10446.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10446'},
#  {'text': "이건 제가 전부터 생각했던 판타스틱 계열 코디예요,  '판타지 타임'이라고 이름 붙여 봤어요.\n",
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10447.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10447'},
#  {'text': '지금은 비록 힘이 없어보여도 믿는 마음이 있다면 반드시 누군가에게 힘이 될 거야.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10448.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10448'},
#  {'text': '예쁘다~ 학교에서도 저런 식으로 웃는다면, 인기가 훨씬 많아질걸?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10449.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10449'},
#  {'text': '얘들아, 배고프지, 이럴 줄 알고 과자 가져 왔는데, 잘했지?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10450.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10450'},
#  {'text': '여기 들어오니까 운동기구가 정말 많다, 어떤 것부터 해 볼까?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10451.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10451'},
#  {'text': '봄날에 잔디밭에서 이렇게 함께 도시락을 나눠 먹으니까 좋네요.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10452.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10452'},
#  {'text': '아빠도 출장 가셨으니까 우리 피자 시켜 먹어요, 엄마 식사 준비 안 해도 되고 좋잖아요!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10453.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10453'},
#  {'text': '요즘 코로나가 잠잠해져서인지 여기저기 축제가 많네요, 오늘 저녁 한강 불꽃놀이 기대된다!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10454.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10454'},
#  {'text': '아침은 아침, 점심은 점심, 저녁은 저녁, 이 중요한 세상 이치를 몰라, 사나이는 밥심이지!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10455.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10455'},
#  {'text': '칭찬 고마워, 누가 뭐래도 내가 믿는 건 나 자신뿐이거든.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10456.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10456'},
#  {'text': '헤이~ 거기 소년, 너가 바로 배지를 9개 모은 녀석이냐, 반갑다, 배틀을 신청한다! \n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10457.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10457'},
#  {'text': '저런 조무래기들을 상대로 다같이 몰려갈 필요없어, 나 혼자 가도 충분해!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10458.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10458'},
#  {'text': '어머어머~ 언니님도 너무 예쁘시다~ 이 집안은 미모가 대물림이네!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10459.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10459'},
#  {'text': '어서 와라, 이번 여행은 조금 오래 걸렸구나, 무사귀환 한 걸 환영한다.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10460.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10460'},
#  {'text': '이걸 정말 맨손으로 때려잡았다고요, 정말 대단하십니다, 나으리!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10461.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10461'},
#  {'text': '각오해 두는 게 좋을 걸, 지금부터 내 무기의 위력을 보여 주마!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10462.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10462'},
#  {'text': '네가 아무리 요괴라도 나는 너랑 사이좋게 지낼 수 있었으면 좋겠어.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10463.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10463'},
#  {'text': '여기서 좀 쉬었다 가자, 봐, 바깥 풍경이 너무 예쁘지 않아.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10464.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10464'},
#  {'text': '저런 풍경을 반찬 삼아 밥 열 공기도 거뜬할 거 같애.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10465.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10465'},
#  {'text': '진짜 싸움은 이제부터야, 내 힘을 보고 놀라지나 말라고!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10466.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10466'},
#  {'text': '중요한 건 내가 그 녀석한테 또다시 이겼다는 사실 아닐까?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10467.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10467'},
#  {'text': '너희들은 걱정할 거 하나도 없어, 나만 믿고 따라오면 돼, 자, 준비됐지?\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10468.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10468'},
#  {'text': '오호~ 기특하게 내 이름을 기억하고 있었네, 이번에는 내 얼굴까지 기억하게 해주지!\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10469.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10469'},
#  {'text': '언젠가는 이곳으로 다시 돌아올 그 녀석을 위해, 우리 지금처럼 여기서 변함없이 기다리자.\n',
#   'audio_file': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1\\wavs\\H10470.wav',
#   'speaker_name': 'ljspeech',
#   'root_path': 'c:\\Users\\jakehan\\OneDrive\\Desktop\\project\\content-remix-studio\\tts-server\\dataset\\actors\\anime_001\\H1',
#   'language': 'ko',
#   'audio_unique_name': 'dragon#wavs\\H10470'}]

# %% [markdown]
# #### 🚀 Run the Tensorboard. 🚀
# On the notebook and Tensorboard, you can monitor the progress of your model. Also Tensorboard provides certain figures and sample outputs.

# %%
# init the trainer and 🚀
trainer = Trainer(
    TrainerArgs(
        restore_path=None,  # xtts checkpoint is restored via xtts_checkpoint key so no need of restore it using Trainer restore_path parameter
        skip_train_epoch=False,
        start_with_eval=START_WITH_EVAL,
        grad_accum_steps=GRAD_ACUMM_STEPS,
    ),
    config,
    output_path=OUT_PATH,
    model=model,
    train_samples=train_samples,
    eval_samples=eval_samples,
)
trainer.fit()
# Out:
#  > Training Environment:
#  | > Backend: Torch
#  | > Mixed precision: False
#  | > Precision: float32
#  | > Num. of CPUs: 12
#  | > Num. of Torch Threads: 1
#  | > Torch seed: 1
#  | > Torch CUDNN: True
#  | > Torch CUDNN deterministic: False
#  | > Torch CUDNN benchmark: False
#  | > Torch TF32 MatMul: False
#  > Start Tensorboard: tensorboard --logdir=./test\run\train_outputs\GPT_XTTS_v2.0-December-04-2024_05+41PM-0000000
#
#  > Model has 518442047 parameters
#
#  > EPOCH: 0/1000
#  --> ./test\run\train_outputs\GPT_XTTS_v2.0-December-04-2024_05+41PM-0000000
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File c:\Users\jakehan\OneDrive\Desktop\project\content-remix-studio\.venv\Lib\site-packages\trainer\trainer.py:1605, in Trainer.fit(self)
#    1604 try:
# -> 1605     self._fit()
#    1606     if self.args.rank == 0:
#
# File c:\Users\jakehan\OneDrive\Desktop\project\content-remix-studio\.venv\Lib\site-packages\trainer\trainer.py:1559, in Trainer._fit(self)
#    1558 if self.config.run_eval:
# -> 1559     self.eval_epoch()
#    1560 if epoch >= self.config.test_delay_epochs and self.args.rank <= 0:
#
# File c:\Users\jakehan\OneDrive\Desktop\project\content-remix-studio\.venv\Lib\site-packages\trainer\trainer.py:1396, in Trainer.eval_epoch(self)
#    1394 if self.eval_loader is None:
#    1395     self.eval_loader = (
# -> 1396         self.get_eval_dataloader(
#    1397             self.training_assets,
#    1398             self.eval_samples,
#    1399             verbose=True,
#    1400         )
#    1401         if self.config.run_eval
#    1402         else None
#    1403     )
#    1405 torch.set_grad_enabled(False)
#
# File c:\Users\jakehan\OneDrive\Desktop\project\content-remix-studio\.venv\Lib\site-packages\trainer\trainer.py:759, in Trainer.get_eval_dataloader(self, training_assets, samples, verbose)
#     757     return self.model.get_eval_data_loader(self.config, self.training_assets, samples, verbose, self.num_gpus)
# --> 759 return self._get_loader(
#     760     self.model,
#     761     self.config,
#     762     training_assets,
#     763     True,
#     764     samples,
#     765     verbose,
#     766     self.num_gpus,
#     767 )
#
# File c:\Users\jakehan\OneDrive\Desktop\project\content-remix-studio\.venv\Lib\site-packages\trainer\trainer.py:691, in Trainer._get_loader(self, model, config, assets, is_eval, samples, verbose, num_gpus)
#     686     loader = model.get_data_loader(
#     687         config=config, assets=assets, is_eval=is_eval, samples=samples, verbose=verbose, num_gpus=num_gpus
#     688     )
#     690 assert (
# --> 691     len(loader) > 0
#     692 ), " ❗ len(DataLoader) returns 0. Make sure your dataset is not empty or len(dataset) > 0. "
#     693 return loader
#
# AssertionError:  ❗ len(DataLoader) returns 0. Make sure your dataset is not empty or len(dataset) > 0.
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[15], line 15
#       1 # init the trainer and 🚀
#       2 trainer = Trainer(
#       3     TrainerArgs(
#       4         restore_path=None,  # xtts checkpoint is restored via xtts_checkpoint key so no need of restore it using Trainer restore_path parameter
#    (...)
#      13     eval_samples=eval_samples,
#      14 )
# ---> 15 trainer.fit()
#
# File c:\Users\jakehan\OneDrive\Desktop\project\content-remix-studio\.venv\Lib\site-packages\trainer\trainer.py:1632, in Trainer.fit(self)
#    1630         os._exit(130)  # pylint: disable=protected-access
#    1631 except BaseException:  # pylint: disable=broad-except
# -> 1632     remove_experiment_folder(self.output_path)
#    1633     traceback.print_exc()
#    1634     sys.exit(1)
#
# File c:\Users\jakehan\OneDrive\Desktop\project\content-remix-studio\.venv\Lib\site-packages\trainer\generic_utils.py:89, in remove_experiment_folder(experiment_path)
#      87 if not checkpoint_files:
#      88     if fs.exists(experiment_path):
# ---> 89         fs.rm(experiment_path, recursive=True)
#      90         logger.info(" ! Run is removed from %s", experiment_path)
#      91 else:
#
# File c:\Users\jakehan\OneDrive\Desktop\project\content-remix-studio\.venv\Lib\site-packages\fsspec\implementations\local.py:183, in LocalFileSystem.rm(self, path, recursive, maxdepth)
#     181     if osp.abspath(p) == os.getcwd():
#     182         raise ValueError("Cannot delete current working directory")
# --> 183     shutil.rmtree(p)
#     184 else:
#     185     os.remove(p)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\shutil.py:787, in rmtree(path, ignore_errors, onerror, dir_fd)
#     785     # can't continue even if onerror hook returns
#     786     return
# --> 787 return _rmtree_unsafe(path, onerror)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\shutil.py:634, in _rmtree_unsafe(path, onerror)
#     632             os.unlink(fullname)
#     633         except OSError:
# --> 634             onerror(os.unlink, fullname, sys.exc_info())
#     635 try:
#     636     os.rmdir(path)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\shutil.py:632, in _rmtree_unsafe(path, onerror)
#     630 else:
#     631     try:
# --> 632         os.unlink(fullname)
#     633     except OSError:
#     634         onerror(os.unlink, fullname, sys.exc_info())
#
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'c:/Users/jakehan/OneDrive/Desktop/project/content-remix-studio/tts-server/test/run/train_outputs/GPT_XTTS_v2.0-December-04-2024_05+41PM-0000000\\trainer_0_log.txt'

# %%
# !pip install tensorboard
# !tensorboard --logdir=tts_train_dir

# %% [markdown]
# ## ✅ Test the model
#
# We made it! 🙌
#
# Let's kick off the testing run, which displays performance metrics.
#
# We're committing the cardinal sin of ML 😈 (aka - testing on our training data) so you don't want to deploy this model into production. In this notebook we're focusing on the workflow itself, so it's forgivable 😇
#
# You can see from the test output that our tiny model has overfit to the data, and basically memorized this one sentence.
#
# When you start training your own models, make sure your testing data doesn't include your training data 😅

# %% [markdown]
# Let's get the latest saved checkpoint.

# %%
import glob, os
output_path = "./test/run/train_outputs"
ckpts = sorted([f for f in glob.glob(output_path+"/*/*.pth")])
configs = sorted([f for f in glob.glob(output_path+"/*/*.json")])

# %%
 # !tts --text "나는 진짜 화가난 상태야  너떄문에!" \
      --model_path $ckpts \
      --config_path $configs \
      --out_path out.wav
# Out:
# usage: tts [-h] [--list_models] [--model_info_by_idx MODEL_INFO_BY_IDX]
#            [--model_info_by_name MODEL_INFO_BY_NAME] [--text TEXT]
#            [--model_name MODEL_NAME] [--vocoder_name VOCODER_NAME]
#            [--config_path CONFIG_PATH] [--model_path MODEL_PATH]
#            [--out_path OUT_PATH] [--use_cuda] [--device DEVICE]
#            [--vocoder_path VOCODER_PATH]
#            [--vocoder_config_path VOCODER_CONFIG_PATH]
#            [--encoder_path ENCODER_PATH]
#            [--encoder_config_path ENCODER_CONFIG_PATH] [--pipe_out]
#            [--speakers_file_path SPEAKERS_FILE_PATH]
#            [--language_ids_file_path LANGUAGE_IDS_FILE_PATH]
#            [--speaker_idx SPEAKER_IDX] [--language_idx LANGUAGE_IDX]
#            [--speaker_wav SPEAKER_WAV [SPEAKER_WAV ...]]
#            [--gst_style GST_STYLE]
#            [--capacitron_style_wav CAPACITRON_STYLE_WAV]
#            [--capacitron_style_text CAPACITRON_STYLE_TEXT]
#            [--list_speaker_idxs] [--list_language_idxs] [--save_spectogram]
#            [--reference_wav REFERENCE_WAV]
#            [--reference_speaker_idx REFERENCE_SPEAKER_IDX]
#            [--progress_bar | --no-progress_bar] [--source_wav SOURCE_WAV]
#            [--target_wav TARGET_WAV] [--voice_dir VOICE_DIR]
# tts: error: unrecognized arguments: './test/run/train_outputs\\XTTS_v2.0_original_model_files\\mel_stats.pth', './test/run/train_outputs\\XTTS_v2.0_original_model_files\\model.pth']

# %% [markdown]
# ## 📣 Listen to the synthesized wave 📣

# %%
import IPython
IPython.display.Audio("out.wav")

# %% [markdown]
# ## 🎉 Congratulations! 🎉 You now have trained your first TTS model!
# Follow up with the next tutorials to learn more advanced material.
